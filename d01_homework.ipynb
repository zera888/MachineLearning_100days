# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
import numpy as np
import matplotlib.pyplot as plt

def mean_absolute_error(y, yp):
    mae=MAE=sum(abs(y-yp))/len(y)
    return mae

def mean_squared_error(y,yp):
    mse=MSE=sum((y-yp)**2)/len(y)
    return mse

# %%
w = 5
b = 0.5
x_lin = np.linspace(0, 200, 201)
y = (x_lin + np.random.randn(201) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc =5)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 5)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 538.007
# The Mean absolute error is 18.856

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 這組資料想解決的問題如何評估
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

# %%
[作業2]

請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：

    你選的這組資料為何重要

    資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)

    蒐集而來的資料型態為何

    這組資料想解決的問題如何評估

回答:
    我選擇的是鐵達尼號沈船事件。這個事件因為已經歷史久遠。所以，事件都已經完全告一段落，不會再有新的數據或資料出來影響分析的結果。
    因為這是歷史上有名的船難事件，所以提供非常重要的資訊。
    這些資料都是由Kaggle提供下載的檔案。都是根據當時事件的生還者或是搭船的乘客的資校彙整而來的。
    這個資料的型態包括姓名、年齡、艙等、家族人數、是否生還等資訊，對於分析非常有用的資料。
    比如性別與生還人數的關係、年齡與生還的關係、艙等與生還之間的關係，都可以探討出非常有用的分析資訊。

# %%
[作業3]

想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

    核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)

    資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)

    蒐集而來的資料型態為何

    你要回答的問題，其如何評估 (tips：你的假設如何驗證)

回答；
        核心問題是把載客車隊視為一個行動的數據收集站。把每天載客中所收集到的所有資訊都整理並且歸納出一定的規則。然後，透過分析這些收集到的數據
        找出影響收益的幾項決定性因素。無論是造成收益上升的正向因素，或是造成收益降低的負面因素，這些都是將來可以分析出問題，並且因此找出對策的
        重要資訊。
        比如載客的路線、地點、時段、天氣、性別、年齡、和政府的活動等等可以交互比對出有效的資訊。這些可以透過客戶的資料，或是車隊所登記的叫車資
        訓而來。或者透過叫車的APP也能蒐集到很多資訊。
        一般蒐集到的資料可以根據資訊內容做分類，放入不同的欄位之中。
        比如某些路段是否叫車的隨機客人比較多?某些地區則是利用APP叫車比較多?某些商業區域，叫車的時間是否和上班族上班時間或是商店的營業時間重疊?
        某些地區則是深夜的客人比較多?可以先提出問題假設，然後根據數據的顯示來映證假說。
